# %% [markdown]
# # Evaluating n-grams across a select number of post translational modification systems
#
# Many reversible post translational modification (PTM) systems operate within a reader-writer-eraser paradigm at the domain level. Many proteins in these systems are multi-domain and in a survey of the domain architectures of the phosphotyrosine system, recurrent patterns can be observed. Whether n-gram analysis can provide insights into the interplay between domain architecture evolution and protein functionality has not been widely explored.

# %%
import pandas as pd
import networkx as nx
import numpy as np
import dansy
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib.lines import Line2D

# %%
# Setting the random seed to be reproducible
import random
random.seed(1)
np.random.seed(1)

# %%
# Creating some default parameters for future plots.
plt.rcParams['font.size'] = 5
plt.rcParams['axes.labelsize'] = 5
plt.rcParams['axes.linewidth'] = 0.5
plt.rcParams['savefig.bbox'] = 'tight'
plt.rcParams['savefig.pad_inches'] = 0.01
plt.rcParams['figure.dpi'] = 300

# For the networks to be drawn later
network_params = {'node_size':3, 'edgecolors':'k',
        'edge_color':"#2C2929", 'width':0.5, 'linewidths':0.25}

# %%
def get_shortest_path_dist(G, source_list, target_list):

    res = pd.Series(dtype=int)
    for s in source_list:
        for t in target_list:
            temp = shortest_path_dist_inner(G, s, t)
            res = res.add(temp, fill_value=0).astype(int)
    
    return res


def shortest_path_dist_inner(G, source, target):

    shortest_paths = nx.all_shortest_paths(G, source, target)
    #shortest_paths = nx.all_simple_paths(G, source, target, cutoff = pl)

    # Now let's look at all the paths and get the number of instances a specific node shows up
    node_path_dist = {}
    try:
        for path in shortest_paths:
            for node in path:
                if node in node_path_dist:
                    node_path_dist[node] += 1
                else:
                    node_path_dist[node] = 1
    except nx.NetworkXNoPath:
        pass
    return pd.Series(node_path_dist,dtype = int)

def get_shortest_path_lens(G, source_list, target_list):
    l = []
    for s in source_list:
        for t in target_list:
            try:
                l.append(nx.shortest_path_length(G, s, t))
            except nx.NetworkXNoPath:
                pass
    return l

# %%
# Importing the reference files for the complete proteome that will then be reduced to the PTM systems of interest
full_ref = dansy.import_proteome_files(ref_file_dir='data/Current_Human_Proteome', ref_file_suffix='2026_0324.csv')

# %%
# Coloring options
writer = 'skyblue'
eraser = 'lightcoral' 
reader = 'sandybrown'
color_cats = {'Reader':reader, 'Writer':writer, 'Eraser':eraser,'Multiple':'mediumpurple', 'External':'lightgray'}

# %% [markdown]
# ## Starting with the phosphotyrosine system

# %%
ptyr_ref = pd.read_csv('data/Current_Multispecies_Files/H_sapiensFull_pTyr_System_Reference_File_2026_0324.csv')

# %%
# Writers
Interpro_ID_ProtKinase = 'IPR000719' #IPR020635 is the actual domain
writer_dom = [Interpro_ID_ProtKinase]

#Erasers
Interpro_ID_PTP = 'IPR000242'
eraser_dom = [Interpro_ID_PTP]

# Readers
Interpro_ID_SH2= 'IPR000980'
Interpro_ID_PTB = 'IPR006020'
reader_dom = [Interpro_ID_SH2,Interpro_ID_PTB]

all_Interpro_IDs = [Interpro_ID_ProtKinase,Interpro_ID_PTP,Interpro_ID_SH2,Interpro_ID_PTB]

# %%
complete_ptyr_net = dansy.dansy(ref = ptyr_ref, n = 10, verbose = False)
system_ptyr_net = dansy.dansy(ref=ptyr_ref, interproIDs=all_Interpro_IDs, n =10, verbose = False)

# %%
# Let's now create the node coloring list based on if the domain has a reader/writer/eraser involved
phos_comp_fig,phos_axs = plt.subplots(2,2, dpi = 300, figsize = (2,2), layout = 'tight')
ptyr_axs = [phos_axs[0,0], phos_axs[1,0]]
for i,d in enumerate([complete_ptyr_net,system_ptyr_net]):
    node_colors = []
    for node in d.G.nodes:
        eraser_check = any([k in node for k in eraser_dom])
        writer_check = any([k in node for k in writer_dom])
        reader_check = any([k in node for k in reader_dom])

        if sum([eraser_check, writer_check, reader_check]) > 1:
            node_colors.append(color_cats['Multiple'])
        elif writer_check:
            node_colors.append(color_cats['Writer'])
        elif eraser_check:
            node_colors.append(color_cats['Eraser'])
        elif reader_check:
            node_colors.append(color_cats['Reader'])
        else:
            node_colors.append(color_cats['External'])
            #raise ValueError(f'Something went very wrong {node}')
        
    pos = nx.nx_agraph.pygraphviz_layout(d.G,prog='sfdp')
    nx.draw(d.G, pos,
            node_color=node_colors,
            **network_params, ax = ptyr_axs[i])
    ptyr_axs[i].axis('on')
    ptyr_axs[i].set_box_aspect(1)
ptyr_axs[0].set_ylabel('Complete')
ptyr_axs[1].set_ylabel('System Focused')
ptyr_axs[0].set_title('pTyr', y =0.96)
plt.close()

# %% [markdown]
# As a way to quantify and demonstrate the number of paths that connect the kinase domain to the PTP domains, we can grab the all the simple paths (where no node is repeated) between the two. However, since there can be a large number we have to limit it to a specific length. For this, we will use the length of the shortest path between the two (and maybe +1)

# %%
shortest_len = nx.shortest_path_length(system_ptyr_net.G, Interpro_ID_ProtKinase, Interpro_ID_PTP)

system_shortest_paths = nx.all_simple_paths(system_ptyr_net.G, Interpro_ID_ProtKinase, Interpro_ID_PTP, cutoff=shortest_len)
complete_shortest_paths = nx.all_simple_paths(complete_ptyr_net.G, Interpro_ID_ProtKinase, Interpro_ID_PTP, cutoff=shortest_len)

# Now let's look at all the paths and get the number of instances a specific node shows up
system_node_path_dist = {}
for path in system_shortest_paths:
    for node in path:
        if node in system_node_path_dist:
            system_node_path_dist[node] += 1
        else:
            system_node_path_dist[node] = 1

system_node_path_dist = pd.Series(system_node_path_dist)

complete_node_path_dist = {}
complete_node_path_dist = {}
for path in complete_shortest_paths:
    for node in path:
        if node in complete_node_path_dist:
            complete_node_path_dist[node] += 1
        else:
            complete_node_path_dist[node] = 1
complete_node_path_dist = pd.Series(complete_node_path_dist)

# %%
# Getting max number of paths which are how often the protein kinase or PTP domain are involved in the path
complete_tot_paths = complete_node_path_dist[Interpro_ID_ProtKinase]
system_tot_paths = system_node_path_dist[Interpro_ID_ProtKinase]
complete_node_path_dist.drop([Interpro_ID_ProtKinase, Interpro_ID_PTP], inplace=True)
system_node_path_dist.drop([Interpro_ID_ProtKinase, Interpro_ID_PTP], inplace=True)

# %%
system_node_path_dist
# Out:
# IPR000980|IPR000719                         1
# IPR000980                                   9
# IPR000980|IPR000980|IPR000242              10
# IPR001452|IPR000980|IPR000719               1
# IPR000299|IPR000980|IPR000719|IPR000719     1
# IPR001849|IPR001452|IPR000980|IPR000719     1
# IPR000980|IPR000980|IPR000719               2
# IPR000980|IPR000980                         1
# IPR001452|IPR000980|IPR000719|IPR015015     1
# IPR001060|IPR000980|IPR000719               1
# IPR001849|IPR000980|IPR000719               1
# IPR001060|IPR037452|IPR000980|IPR000719     1
# dtype: int64

# %%
# Creating a potential figure that will hold a supplemental figure containing all PTM systems writer to eraser and writer to reader histograms
ptm_path_analysis_f, ptm_path_analysis_axs = plt.subplots(5,2, layout = 'tight', dpi =300, figsize=(3,3.5), sharex = True, sharey=True)
plt.close()

# %%
# For the potential supplemental figure now getting the path node distributions
wr = get_shortest_path_dist(system_ptyr_net.G, writer_dom, reader_dom)
wr_tots = wr.filter(reader_dom+writer_dom).max()
wr.drop(reader_dom+writer_dom, inplace = True)
w = np.ones(len(wr))/len(wr)
ptm_path_analysis_axs[0,0].hist(wr.div(wr_tots),
            bins = 20,range=(0,1), 
            weights = w,
            edgecolor = 'k',linewidth = 0.5,
            color = 'tab:green'
            );

we = get_shortest_path_dist(system_ptyr_net.G, writer_dom, eraser_dom)
we_tots = we.filter(eraser_dom+writer_dom).max()
we.drop(eraser_dom+writer_dom, inplace = True)
w = np.ones(len(we))/len(we)
ptm_path_analysis_axs[0,1].hist(we.div(we_tots),
            bins = 20,range=(0,1), 
            weights = w,
            edgecolor = 'k',linewidth = 0.5,
            color = 'tab:green'
            );
xy = (0.65,0.6)
annot_bbox = {'facecolor':'w', 'edgecolor':'k', 'lw':0.35,'boxstyle':'Square, pad = 0.3'}
ptm_path_analysis_axs[0,0].annotate(f'Nodes: {len(wr)}\nPaths: {wr_tots}',xy,bbox = annot_bbox);
ptm_path_analysis_axs[0,1].annotate(f'Nodes: {len(we)}\nPaths: {we_tots}',xy,bbox = annot_bbox);

# %%
# Getting the shortest path lengths between the writer-eraser and writer-reader
ptm_shortest_lens = {}
wr_len = get_shortest_path_lens(system_ptyr_net.G, writer_dom, reader_dom)
we_len = get_shortest_path_lens(system_ptyr_net.G, writer_dom, eraser_dom)
ptm_shortest_lens['pTyr'] = {'reader':wr_len,'eraser':we_len}

# %%
# Now creating two plots that show the distribution of the path lengths
comp_weights = np.ones(len(complete_node_path_dist))/len(complete_node_path_dist)
sys_weights = np.ones(len(system_node_path_dist))/len(system_node_path_dist)

simple_path_fig, simple_path_axs = plt.subplots(2,2, sharex=True, sharey=True, dpi = 300, figsize = (3,2.25), layout = 'tight')
annot_bbox = {'facecolor':'w', 'edgecolor':'k', 'lw':0.35,'boxstyle':'Square, pad = 0.3'}
annotxy = (0.6,0.65)
axs = [simple_path_axs[0,0],simple_path_axs[1,0]]

axs[0].hist(complete_node_path_dist.div(complete_tot_paths),align = 'mid',
             bins = 20, range=(0,1),
             weights = comp_weights,
             edgecolor = 'k', linewidth = 0.5,
             color = '#98df8a')
axs[1].hist(system_node_path_dist.div(system_tot_paths),align = 'mid',
            bins = 20,range=(0,1), 
            weights = sys_weights,
            edgecolor = 'k',linewidth = 0.5,
            color = '#2ca02c'
            )

axs[0].annotate(f'Nodes: {len(complete_node_path_dist)}\nPaths: {complete_tot_paths}',annotxy,bbox = annot_bbox)
axs[1].annotate(f'Nodes: {len(system_node_path_dist)}\nPaths: {system_tot_paths}',annotxy,bbox = annot_bbox)

#axs[1].set_title('System Focused', pad = 2)
axs[1].set_xlabel('Relative Fraction of Paths', labelpad = 2)
axs[0].set_title('pTyr', pad = 4)
for i in range(2):
    axs[i].grid('major', lw = 0.35, ls = '--', color = 'k', zorder = -1)
    axs[i].tick_params('both', length = 3, width = 0.35, pad =1)
    axs[i].set_axisbelow(True)
    #axs[i].set_box_aspect(0.5)

axs[0].set_ylabel('Relative Fraction\nof Nodes')
axs[1].set_ylabel('Relative Fraction\nof Nodes')
plt.close()

# %%
# Generate a dataframe of connected components for each PTM for a summary graph.
ptm_nNet_summary = pd.DataFrame(index=['pY','pST','M','A','U'], columns = ['CC','Isolates','CC Full','Isolates Full'])
ptm_nNet_summary.loc['pY','CC'] = nx.number_connected_components(system_ptyr_net.G)
ptm_nNet_summary.loc['pY','Isolates'] = nx.number_of_isolates(system_ptyr_net.G)

# Adding in the number of connected components in the full ngram network
ptm_nNet_summary.loc['pY','CC Full'] = nx.number_connected_components(complete_ptyr_net.G)
ptm_nNet_summary.loc['pY','Isolates Full'] = nx.number_of_isolates(complete_ptyr_net.G)

# %%
path_analysis ={}
full_wr_paths = []
full_we_paths = []
for d in writer_dom:

    # Double-check if one of the domains has been collapsed
    if d in system_ptyr_net.collapsed_ngrams:
        potent_ngrams = [x for x in system_ptyr_net.ngrams if d in x ]
        ngram_check = min(potent_ngrams, key = lambda x: len(x.split('|')))
    else:
        ngram_check = d
    wr_paths = nx.all_simple_paths(system_ptyr_net.G, ngram_check, reader_dom, cutoff=6)
    we_paths = nx.all_simple_paths(system_ptyr_net.G, ngram_check, eraser_dom, cutoff=6)
    full_wr_paths += list(wr_paths)
    full_we_paths += list(we_paths)

path_analysis['pTyr'] = {'eraser':full_we_paths, 'reader':full_wr_paths}

# %% [markdown]
# # The phosphoserine/threonine system

# %%
# Importing the reader-writer-eraser system of interest

# Writer
Interpro_ID_ProtKinase = 'IPR000719' #IPR001245 is the actual domain ID with ...719 being the protein kinase family
writer_dom = [Interpro_ID_ProtKinase]

# Eraser
Interpro_ID_PhosP = 'IPR004843' # Note IPR006186 is the phosphatase domain's actual ID but it is a child of the calcineurin one
Interpro_ID_PPM = 'IPR001932'
Interpro_ID_FCP= 'IPR004274'
Interpro_ID_Dual_SP = 'IPR000340'
eraser_dom = [Interpro_ID_PhosP, Interpro_ID_PPM,Interpro_ID_FCP,Interpro_ID_Dual_SP]

# Reader domains
Interpro_ID_WW = 'IPR001202'

Interpro_ID_1433 = 'IPR023410'


Interpro_ID_FHA = 'IPR000253'


Interpro_ID_MH2 = 'IPR001132'


Interpro_ID_BRCT = 'IPR001357'


Interpro_ID_FF = 'IPR002713'
reader_dom = [Interpro_ID_WW,Interpro_ID_1433,Interpro_ID_FHA,Interpro_ID_MH2, Interpro_ID_BRCT,Interpro_ID_FF]

all_Interpro_IDs = [Interpro_ID_ProtKinase, Interpro_ID_PhosP,Interpro_ID_PPM,Interpro_ID_FCP, Interpro_ID_WW, Interpro_ID_1433, Interpro_ID_FHA, Interpro_ID_MH2,Interpro_ID_BRCT,Interpro_ID_FF,Interpro_ID_Dual_SP]

# %%
pst_ref = pd.read_csv('data/Current_Multispecies_Files/H_sapiensFull_pSerThr_System_Reference_File_2026_0324.csv')

# As a precaution need to remove the pTyr kinases from this list
ptyr_kins = system_ptyr_net.retrieve_ngram_protein_info('IPR000719')['UniProt ID'].tolist()
pst_ref = pst_ref[~pst_ref['UniProt ID'].isin(ptyr_kins)]

# %%
complete_pst_net = dansy.dansy(ref = pst_ref, n = 10, verbose = False)
system_pst_net = dansy.dansy(ref=pst_ref, interproIDs=all_Interpro_IDs, n =10, verbose = False)

# %%
# Let's now create the node coloring list based on if the domain has a reader/writer/eraser involved
network_params = {'node_size':2, 'edgecolors':'k',
        'edge_color':"#2C2929", 'width':0.5, 'linewidths':0.25}
pst_axs = [phos_axs[0,1], phos_axs[1,1]]
for i,d in enumerate([complete_pst_net,system_pst_net]):
    node_colors = []
    for node in d.G.nodes:
        eraser_check = any([k in node for k in eraser_dom])
        writer_check = any([k in node for k in writer_dom])
        reader_check = any([k in node for k in reader_dom])

        if sum([eraser_check, writer_check, reader_check]) > 1:
            node_colors.append(color_cats['Multiple'])
        elif writer_check:
            node_colors.append(color_cats['Writer'])
        elif eraser_check:
            node_colors.append(color_cats['Eraser'])
        elif reader_check:
            node_colors.append(color_cats['Reader'])
        else:
            node_colors.append(color_cats['External'])
            #raise ValueError(f'Something went very wrong {node}')
        
    pos = nx.nx_agraph.pygraphviz_layout(d.G,prog='sfdp')
    nx.draw(d.G, pos,
            node_color=node_colors,
            **network_params, ax = pst_axs[i])
    pst_axs[i].axis('on')
    pst_axs[i].set_box_aspect(1)

pst_axs[0].set_title('pSer/Thr', y =0.96)
# Now adding legends to both figures
handles = [Line2D([],[], marker='o', color=v, markersize=4,linestyle='None', markeredgecolor='k', markeredgewidth=0.25) for v in color_cats.values()]
labels = [k for k in color_cats.keys()]
phos_comp_fig.legend(handles, labels, fancybox = False, edgecolor = 'k',loc = 'lower center', ncols = 3,
                borderpad = 0.2, columnspacing = 0.5, handletextpad = 0.25,
                bbox_to_anchor = (0.5,-0.1)).get_frame().set_linewidth(0.5)
phos_comp_fig.savefig('Figures/Manuscript/Figure_2/2Ai_Phospho_Network_Comparison.svg')
phos_comp_fig

# %%
potent_shortest_len = nx.single_source_shortest_path_length(system_pst_net.G, Interpro_ID_ProtKinase)
shortest_len = min([v for k,v in potent_shortest_len.items() if k in eraser_dom])

system_shortest_paths = nx.all_simple_paths(system_pst_net.G, Interpro_ID_ProtKinase, eraser_dom, cutoff=shortest_len)
complete_shortest_paths = nx.all_simple_paths(complete_pst_net.G, Interpro_ID_ProtKinase, eraser_dom, cutoff=shortest_len)

# Now let's look at all the paths and get the number of instances a specific node shows up
system_node_path_dist = {}
for path in system_shortest_paths:
    for node in path:
        if node in system_node_path_dist:
            system_node_path_dist[node] += 1
        else:
            system_node_path_dist[node] = 1

system_node_path_dist = pd.Series(system_node_path_dist)

complete_node_path_dist = {}
for path in complete_shortest_paths:
    for node in path:
        if node in complete_node_path_dist:
            complete_node_path_dist[node] += 1
        else:
            complete_node_path_dist[node] = 1
complete_node_path_dist = pd.Series(complete_node_path_dist)

# %%
# Getting max number of paths which are how often the protein kinase or PTP domain are involved in the path
complete_tot_paths = complete_node_path_dist[Interpro_ID_ProtKinase]
system_tot_paths = system_node_path_dist[Interpro_ID_ProtKinase]
complete_node_path_dist.drop([Interpro_ID_ProtKinase]+[e for e in eraser_dom if e in complete_node_path_dist.index], inplace=True)
system_node_path_dist.drop([Interpro_ID_ProtKinase]+[e for e in eraser_dom if e in complete_node_path_dist.index], inplace=True)

# %%
complete_pst_net.return_legible_ngram('IPR055071|IPR001849|IPR001932')
# Out:
# 'RA_PHLPP-like|PH_domain|PPM-type_phosphatase-like_dom'

# %%
complete_node_path_dist
# Out:
# IPR000719|IPR000961                                                                                     143
# IPR016137|IPR000719|IPR000961                                                                             8
# IPR016137|IPR000719|IPR000961|IPR001849                                                                  31
# IPR001849                                                                                              1384
# IPR055071|IPR001849|IPR001932                                                                          1384
#                                                                                                        ...
# IPR003961|IPR000719|IPR003598|IPR003598|IPR003598|IPR003598|IPR003598|IPR003598|IPR003598|IPR003598      21
# IPR003961|IPR003961|IPR003598|IPR003598|IPR003961|IPR003961|IPR003598|IPR003599|IPR003961|IPR000719      23
# IPR000719|IPR003598|IPR003598|IPR003598|IPR003598|IPR003598|IPR003598|IPR003598|IPR003598|IPR003598      14
# ...

# %%
# For the supplemental figure now getting the path node distributions
i = 1
wr = get_shortest_path_dist(system_pst_net.G, writer_dom, reader_dom)
wr_tots = wr.filter(reader_dom+writer_dom).max()
wr.drop([x for x in reader_dom+writer_dom if x in wr.index], inplace = True)
w = np.ones(len(wr))/len(wr)
ptm_path_analysis_axs[1,0].hist(wr.div(wr_tots),
            bins = 20,range=(0,1), 
            weights = w,
            edgecolor = 'k',linewidth = 0.5,
            color = 'tab:purple'
            );

we = get_shortest_path_dist(system_pst_net.G, writer_dom, eraser_dom)
we_tots = we.filter(eraser_dom+writer_dom).max()
we.drop([x for x in eraser_dom+writer_dom if x in we.index], inplace = True)
w = np.ones(len(we))/len(we)
ptm_path_analysis_axs[1,1].hist(we.div(we_tots),
            bins = 20,range=(0,1), 
            weights = w,
            edgecolor = 'k',linewidth = 0.5,
            color = 'tab:purple'
            );
ptm_path_analysis_axs[i,0].annotate(f'Nodes: {len(wr)-2}\nPaths: {wr_tots}',xy,bbox = annot_bbox);
ptm_path_analysis_axs[i,1].annotate(f'Nodes: {len(we)-2}\nPaths: {we_tots}',xy,bbox = annot_bbox);

# %%
sources = []
for d in writer_dom:
    if d in system_pst_net.collapsed_ngrams:
            potent_ngrams = [x for x in system_pst_net.ngrams if d in x ]
            ngram_check = min(potent_ngrams, key = lambda x: len(x.split('|')))
    else:
        ngram_check = d
    sources.append(ngram_check)

r_targets = []
for d in reader_dom:
    if d in system_pst_net.collapsed_ngrams:
            potent_ngrams = [x for x in system_pst_net.ngrams if d in x ]
            ngram_check = min(potent_ngrams, key = lambda x: len(x.split('|')))
    else:
        ngram_check = d
    r_targets.append(ngram_check)

e_targets = []
for d in eraser_dom:
    if d in system_pst_net.collapsed_ngrams:
            potent_ngrams = [x for x in system_pst_net.ngrams if d in x ]
            ngram_check = min(potent_ngrams, key = lambda x: len(x.split('|')))
    else:
        ngram_check = d
    e_targets.append(ngram_check)

wr_len = get_shortest_path_lens(system_pst_net.G, sources, r_targets)
we_len = get_shortest_path_lens(system_pst_net.G, sources, e_targets)
ptm_shortest_lens['pSerThr'] = {'reader':wr_len,'eraser':we_len}

# %%
[complete_pst_net.return_legible_ngram(k) for k in system_node_path_dist.sort_values(ascending=False).index]
# Out:
# ['FHA_dom|Prot_kinase_dom',
#  'FHA_dom',
#  'BRCT_dom',
#  'BSH_FCP1|FCP1_dom|BRCT_dom|FCP1_C',
#  'FCP1_dom',
#  'FHA_dom|BRCT_dom',
#  'FHA_dom|BRCT_dom|Nibrin_BRCT2|Nibrin_C',
#  'FHA_dom|BRCT_dom|BRCT_dom']

# %%
# Now creating two plots that show the distribution of the path lengths
comp_weights = np.ones(len(complete_node_path_dist))/len(complete_node_path_dist)
sys_weights = np.ones(len(system_node_path_dist))/len(system_node_path_dist)

axs = [simple_path_axs[0,1],simple_path_axs[1,1]]

axs[0].hist(complete_node_path_dist.div(complete_tot_paths),align = 'mid',
             bins = 20, range=(0,1),
             weights = comp_weights,
             edgecolor = 'k', linewidth = 0.5,
             color = '#c5b0d5')
axs[1].hist(system_node_path_dist.div(system_tot_paths),align = 'mid',
            bins = 20,range=(0,1), 
            weights = sys_weights,
            edgecolor = 'k',linewidth = 0.5,
            color = '#9467bd'
            )

# Adding the number of nodes and paths
axs[0].annotate(f'Nodes: {len(complete_node_path_dist)-2}\nPaths: {complete_tot_paths}',annotxy,bbox = annot_bbox)
axs[1].annotate(f'Nodes: {len(system_node_path_dist)-2}\nPaths: {system_tot_paths}',annotxy,bbox = annot_bbox)

#axs[1].set_title('System Focused', pad = 2)
axs[1].set_xlabel('Relative Fraction of Paths',labelpad = 2)
axs[0].set_title('Ser/Thr', pad = 4)

for i in range(2):
    #axs[i].set_ylabel('Relative Fraction\nof Nodes')
    axs[i].grid('major', lw = 0.35, ls = '--', color = 'k', zorder = -1)
    axs[i].tick_params('both', length = 3, width = 0.35, pad =1)
    axs[i].set_axisbelow(True)
    #axs[i].set_box_aspect(0.5)
simple_path_fig.suptitle('Simple Paths from Writers to Erasers', y =0.95,x = 0.55)
simple_path_fig.savefig('Figures/Manuscript/Figure_2/2Aii_Simple_Path_Analysis.svg')
simple_path_fig

# %%
[c for c in nx.connected_components(system_pst_net.G) if len(c) <= 10]
# Out:
# [{'IPR000340',
#   'IPR000340|IPR001339|IPR013846',
#   'IPR000340|IPR013087',
#   'IPR001763|IPR000340',
#   'IPR043588|IPR014876|IPR000340'},
#  {'IPR001932',
#   'IPR001932|IPR012911',
#   'IPR055071|IPR001849|IPR001932',
#   'IPR055071|IPR001932'},
#  {'IPR004843',
#   'IPR013235|IPR004843',
#   'IPR013235|IPR004843|IPR002048|IPR002048',
#   'IPR031675|IPR004843'},
#  {'IPR003619|IPR001132'},
#  {'IPR023410'}]

# %%
[c for c in nx.connected_components(complete_pst_net.G) if len(c) <= 10]
# Out:
# [{'IPR004843',
#   'IPR013235|IPR004843',
#   'IPR013235|IPR004843|IPR002048|IPR002048',
#   'IPR031675|IPR004843'},
#  {'IPR003619|IPR001132'},
#  {'IPR023410'}]

# %%
# Adding in the number of connected components in the full ngram network
ptm_nNet_summary.loc['pST','CC'] = nx.number_connected_components(system_pst_net.G)
ptm_nNet_summary.loc['pST','Isolates'] = nx.number_of_isolates(system_pst_net.G)
ptm_nNet_summary.loc['pST','CC Full'] = nx.number_connected_components(complete_pst_net.G)
ptm_nNet_summary.loc['pST','Isolates Full'] = nx.number_of_isolates(complete_pst_net.G)

# %%
full_wr_paths = []
full_we_paths = []
for d in writer_dom:

    # Double-check if one of the domains has been collapsed
    if d in system_pst_net.collapsed_ngrams:
        potent_ngrams = [x for x in system_pst_net.ngrams if d in x ]
        ngram_check = min(potent_ngrams, key = lambda x: len(x.split('|')))
    else:
        ngram_check = d
    wr_paths = nx.all_simple_paths(system_pst_net.G, ngram_check, reader_dom, cutoff=6)
    we_paths = nx.all_simple_paths(system_pst_net.G, ngram_check, eraser_dom, cutoff=6)
    full_wr_paths += list(wr_paths)
    full_we_paths += list(we_paths)

path_analysis['pSerThr'] = {'eraser':full_we_paths, 'reader':full_wr_paths}

# %% [markdown]
# # Expanding to additional reversible PTM systems
#
# Below we expand to 3 additional PTM systems: acetylation, methylation, and ubiquination.
#
# For each we will use DANSy to extract both the Complete and System Focused networks, but will only provide network visualizations of the System Focused networks. The connected component analysis for both are provided, but only the System Focused is presented in the manuscript.

# %% [markdown]
# ## Acetylation

# %%
# Writers (lots of these)
Interpro_ID_MSYT = 'IPR002717'
Interpro_ID_CBP = 'IPR031162'
Interpro_ID_TAF1 = 'IPR022591'
Interpro_ID_GNAT = 'IPR000182'
writer_dom = [Interpro_ID_MSYT, Interpro_ID_CBP, Interpro_ID_TAF1, Interpro_ID_GNAT]

# Erasers
Interpro_ID_HDAC = 'IPR023801'
Interpro_ID_SIRT = 'IPR026590'
eraser_dom = [Interpro_ID_HDAC,Interpro_ID_SIRT]

# Reader
Interpro_ID_Bromo = 'IPR001487'
reader_dom = [Interpro_ID_Bromo]

all_Interpro_IDs = [Interpro_ID_MSYT, Interpro_ID_CBP,Interpro_ID_TAF1,Interpro_ID_GNAT,Interpro_ID_HDAC,Interpro_ID_SIRT,Interpro_ID_Bromo]

# %%
acetyl_prots = full_ref[full_ref['Interpro Domain Architecture IDs'].apply(lambda y: any([x in y for x in all_Interpro_IDs]))]

# %%
complete_acetyl_net = dansy.dansy(ref = acetyl_prots, n = 10, verbose = False)
system_acetyl_net = dansy.dansy(ref=acetyl_prots, interproIDs=all_Interpro_IDs, n =10, verbose = False)

# %%
# Setting up the combined network visualization plot
ptm_nets_fig, ptm_nets_axs = plt.subplots(1,3, layout = 'tight', dpi = 300, figsize = (3.2,1.2))
plt.close()

# %%
d=system_acetyl_net
node_colors = []
for node in d.G.nodes:
    eraser_check = any([k in node for k in eraser_dom])
    writer_check = any([k in node for k in writer_dom])
    reader_check = any([k in node for k in reader_dom])

    if sum([eraser_check, writer_check, reader_check]) > 1:
        node_colors.append(color_cats['Multiple'])
    elif writer_check:
        node_colors.append(color_cats['Writer'])
    elif eraser_check:
        node_colors.append(color_cats['Eraser'])
    elif reader_check:
        node_colors.append(color_cats['Reader'])
    else:
        node_colors.append(color_cats['External'])
        #raise ValueError(f'Something went very wrong {node}')
    
pos = nx.nx_agraph.pygraphviz_layout(d.G,prog='sfdp')
nx.draw(d.G, pos,
        node_color=node_colors,
        **network_params, ax=ptm_nets_axs[1])
ptm_nets_axs[1].set_title('Acetylation')
# Out:
# Text(0.5, 1.0, 'Acetylation')

# %%
# Adding in the number of connected components in the full ngram network
ptm_nNet_summary.loc['A','CC'] = nx.number_connected_components(system_acetyl_net.G)
ptm_nNet_summary.loc['A','Isolates'] = nx.number_of_isolates(system_acetyl_net.G)
ptm_nNet_summary.loc['A','CC Full'] = nx.number_connected_components(complete_acetyl_net.G)
ptm_nNet_summary.loc['A','Isolates Full'] = nx.number_of_isolates(complete_acetyl_net.G)

# %%
temp =[x for x in system_acetyl_net.ngrams if 'IPR031162' in x ]
min(temp, key = lambda x: len(x.split('|')))
# Out:
# 'IPR000197|IPR003101|IPR001487|IPR010303|IPR056484|IPR031162'

# %%
i = 3

sources = []
for d in writer_dom:
    if d in system_acetyl_net.collapsed_ngrams:
            potent_ngrams = [x for x in system_acetyl_net.ngrams if d in x ]
            ngram_check = min(potent_ngrams, key = lambda x: len(x.split('|')))
    else:
        ngram_check = d

    sources.append(ngram_check)

targets = []
for d in reader_dom:
    if d in system_acetyl_net.collapsed_ngrams:
            potent_ngrams = [x for x in system_acetyl_net.ngrams if d in x ]
            ngram_check = min(potent_ngrams, key = lambda x: len(x.split('|')))
    else:
        ngram_check = d

    targets.append(ngram_check)


wr = get_shortest_path_dist(system_acetyl_net.G, sources, targets)
wr_tots = wr.filter(sources+targets).max()
wr.drop([x for x in sources+targets if x in wr.index], inplace = True)
w = np.ones(len(wr))/len(wr)
ptm_path_analysis_axs[i,0].hist(wr.div(wr_tots),
            bins = 20,range=(0,1), 
            weights = w,
            edgecolor = 'k',linewidth = 0.5,
            color = 'tab:pink'
            );

targets = []
for d in eraser_dom:
    if d in system_acetyl_net.collapsed_ngrams:
            potent_ngrams = [x for x in system_acetyl_net.ngrams if d in x ]
            ngram_check = min(potent_ngrams, key = lambda x: len(x.split('|')))
    else:
        ngram_check = d

    targets.append(ngram_check)

we = get_shortest_path_dist(system_acetyl_net.G, sources, targets)
we_tots = we.filter(sources+targets).max()
we.drop([x for x in sources+targets if x in we.index], inplace = True)
w = np.ones(len(we))/len(we)
ptm_path_analysis_axs[i,1].hist(we.div(we_tots),
            bins = 20,range=(0,1), 
            weights = w,
            edgecolor = 'k',linewidth = 0.5,
            color = 'tab:pink'
            );
if np.isnan(wr_tots):
    wr_tots = 0
if np.isnan(we_tots):
    we_tots = 0
ptm_path_analysis_axs[i,0].annotate(f'Nodes: {len(wr)}\nPaths: {wr_tots}',xy,bbox = annot_bbox);
ptm_path_analysis_axs[i,1].annotate(f'Nodes: {len(we)}\nPaths: {we_tots}',xy,bbox = annot_bbox);

# %%
sources = []
for d in writer_dom:
    if d in system_acetyl_net.collapsed_ngrams:
            potent_ngrams = [x for x in system_acetyl_net.ngrams if d in x ]
            ngram_check = min(potent_ngrams, key = lambda x: len(x.split('|')))
    else:
        ngram_check = d
    sources.append(ngram_check)

r_targets = []
for d in reader_dom:
    if d in system_acetyl_net.collapsed_ngrams:
            potent_ngrams = [x for x in system_acetyl_net.ngrams if d in x ]
            ngram_check = min(potent_ngrams, key = lambda x: len(x.split('|')))
    else:
        ngram_check = d
    r_targets.append(ngram_check)

e_targets = []
for d in eraser_dom:
    if d in system_acetyl_net.collapsed_ngrams:
            potent_ngrams = [x for x in system_acetyl_net.ngrams if d in x ]
            ngram_check = min(potent_ngrams, key = lambda x: len(x.split('|')))
    else:
        ngram_check = d
    e_targets.append(ngram_check)

wr_len = get_shortest_path_lens(system_acetyl_net.G, sources, r_targets)
we_len = get_shortest_path_lens(system_acetyl_net.G, sources, e_targets)
ptm_shortest_lens['Acetylation'] = {'reader':wr_len,'eraser':we_len}

# %% [markdown]
# # Ubiquination

# %%
# Importing all the ubiquitin associated system

# Writer system (including the e1 and e2 enzymes not just ligases)

Interpro_ID_hect = 'IPR000569'


Interpro_ID_thif = 'IPR000594'


Interpro_ID_UBQ = 'IPR000608'


writer_dom = [Interpro_ID_hect,Interpro_ID_thif,Interpro_ID_UBQ]

# Readers

Interpro_ID_lz = 'IPR032419'


Interpro_ID_UBA = 'IPR015940'


Interpro_ID_GAT = 'IPR004152'


Interpro_ID_CUE = 'IPR003892'


# These two also have some eraser capabilities it seems but primarily act as readers so will be classified as such
Interpro_ID_znfubz = 'IPR041641'


Interpro_ID_znfUBP = 'IPR001607'


reader_dom = [Interpro_ID_lz,Interpro_ID_UBA,Interpro_ID_GAT,Interpro_ID_CUE, Interpro_ID_znfubz,Interpro_ID_znfUBP]

# These are actual erasers
Interpro_ID_OTU = 'IPR003323'


Interpro_ID_usp = 'IPR028889'
InterproID_U19_UCH = 'IPR001394'


Interpro_ID_jamm = 'IPR000555'


Interpro_ID_josephin = 'IPR006155'


eraser_dom = [Interpro_ID_OTU,Interpro_ID_usp,Interpro_ID_jamm, Interpro_ID_josephin, InterproID_U19_UCH]


all_Interpro_IDs = [Interpro_ID_hect,Interpro_ID_thif,Interpro_ID_UBQ,Interpro_ID_lz,Interpro_ID_UBA,Interpro_ID_GAT,Interpro_ID_CUE,Interpro_ID_znfubz,Interpro_ID_znfUBP, Interpro_ID_OTU,Interpro_ID_jamm,Interpro_ID_usp,InterproID_U19_UCH,Interpro_ID_josephin]

# %%
ubiq_prots = full_ref[full_ref['Interpro Domain Architecture IDs'].apply(lambda y: any([x in y for x in all_Interpro_IDs]))]
complete_ubiq_net = dansy.dansy(ref = ubiq_prots, n = 10, verbose = False)
system_ubiq_net = dansy.dansy(ref=ubiq_prots, interproIDs=all_Interpro_IDs, n =10, verbose = False)

# %%
d = system_ubiq_net
node_colors = []
for node in d.G.nodes:
    eraser_check = any([k in node for k in eraser_dom])
    writer_check = any([k in node for k in writer_dom])
    reader_check = any([k in node for k in reader_dom])

    if sum([eraser_check, writer_check, reader_check]) > 1:
        node_colors.append(color_cats['Multiple'])
    elif writer_check:
        node_colors.append(color_cats['Writer'])
    elif eraser_check:
        node_colors.append(color_cats['Eraser'])
    elif reader_check:
        node_colors.append(color_cats['Reader'])
    else:
        node_colors.append(color_cats['External'])
        #raise ValueError(f'Something went very wrong {node}')
    
pos = nx.nx_agraph.pygraphviz_layout(d.G,prog='sfdp')
nx.draw(d.G, pos,
        node_color=node_colors,
        **network_params,
        ax= ptm_nets_axs[2])
ptm_nets_axs[2].set_title('Ubiquitination')
# Out:
# Text(0.5, 1.0, 'Ubiquitination')

# %%
for node in system_ubiq_net.G.nodes:
        eraser_check = any([k in node for k in eraser_dom])
        writer_check = any([k in node for k in writer_dom])
        reader_check = any([k in node for k in reader_dom])

        if sum([eraser_check, writer_check, reader_check]) > 1:
            print(system_ubiq_net.return_legible_ngram(node))
# Out:
# Znf_UBP|Peptidase_C19_UCH
# Znf_UBP|Peptidase_C19_UCH|Pept_C19_DUSP|Pept_C19_DUSP
# UBP13_Znf-UBP_var|Znf_UBP|Peptidase_C19_UCH
# E3_Ub_ligase_DUF908|E3_Ub_ligase_DUF913|UBA|WWE_dom|HECT_dom
# UBC|UBA
# UBA|ARM_UBP34_24_USP9X_Y|UBP24_Ubl|Peptidase_C19_UCH

# %%
# Adding in the number of connected components in the full ngram network
ptm_nNet_summary.loc['U','CC'] = nx.number_connected_components(system_ubiq_net.G)
ptm_nNet_summary.loc['U','Isolates'] = nx.number_of_isolates(system_ubiq_net.G)
ptm_nNet_summary.loc['U','CC Full'] = nx.number_connected_components(complete_ubiq_net.G)
ptm_nNet_summary.loc['U','Isolates Full'] = nx.number_of_isolates(complete_ubiq_net.G)

# %%
sources = []
for d in writer_dom:
    if d in system_ubiq_net.collapsed_ngrams:
            potent_ngrams = [x for x in system_ubiq_net.ngrams if d in x ]
            ngram_check = min(potent_ngrams, key = lambda x: len(x.split('|')))
    else:
        ngram_check = d
    sources.append(ngram_check)

r_targets = []
for d in reader_dom:
    if d in system_ubiq_net.collapsed_ngrams:
            potent_ngrams = [x for x in system_ubiq_net.ngrams if d in x ]
            ngram_check = min(potent_ngrams, key = lambda x: len(x.split('|')))
    else:
        ngram_check = d
    r_targets.append(ngram_check)

e_targets = []
for d in eraser_dom:
    if d in system_ubiq_net.collapsed_ngrams:
            potent_ngrams = [x for x in system_ubiq_net.ngrams if d in x ]
            ngram_check = min(potent_ngrams, key = lambda x: len(x.split('|')))
    else:
        ngram_check = d
    e_targets.append(ngram_check)

wr_len = get_shortest_path_lens(system_ubiq_net.G, sources, r_targets)
we_len = get_shortest_path_lens(system_ubiq_net.G, sources, e_targets)
ptm_shortest_lens['Ubiquitination'] = {'reader':wr_len,'eraser':we_len}

# %%
i = 4

sources = []
for d in writer_dom:
    if d in system_ubiq_net.collapsed_ngrams:
            potent_ngrams = [x for x in system_ubiq_net.ngrams if d in x ]
            ngram_check = min(potent_ngrams, key = lambda x: len(x.split('|')))
    else:
        ngram_check = d

    sources.append(ngram_check)

targets = []
for d in reader_dom:
    if d in system_ubiq_net.collapsed_ngrams:
            potent_ngrams = [x for x in system_ubiq_net.ngrams if d in x ]
            ngram_check = min(potent_ngrams, key = lambda x: len(x.split('|')))
    else:
        ngram_check = d

    targets.append(ngram_check)


wr = get_shortest_path_dist(system_ubiq_net.G, sources, targets)
wr_tots = wr.filter(sources+targets).max()
wr.drop([x for x in sources+targets if x in wr.index], inplace = True)
w = np.ones(len(wr))/len(wr)
ptm_path_analysis_axs[i,0].hist(wr.div(wr_tots),
            bins = 20,range=(0,1), 
            weights = w,
            edgecolor = 'k',linewidth = 0.5,
            color = 'tab:gray'
            );

targets = []
for d in eraser_dom:
    if d in system_ubiq_net.collapsed_ngrams:
            potent_ngrams = [x for x in system_ubiq_net.ngrams if d in x ]
            ngram_check = min(potent_ngrams, key = lambda x: len(x.split('|')))
    else:
        ngram_check = d

    targets.append(ngram_check)

we = get_shortest_path_dist(system_ubiq_net.G, sources, targets)
we_tots = we.filter(sources+targets).max()
we.drop([x for x in sources+targets if x in we.index], inplace = True)
w = np.ones(len(we))/len(we)
ptm_path_analysis_axs[i,1].hist(we.div(we_tots),
            bins = 20,range=(0,1), 
            weights = w,
            edgecolor = 'k',linewidth = 0.5,
            color = 'tab:gray'
            );
if np.isnan(wr_tots):
    wr_tots = 0
if np.isnan(we_tots):
    we_tots = 0
ptm_path_analysis_axs[i,0].annotate(f'Nodes: {len(wr)}\nPaths: {wr_tots}',xy,bbox = annot_bbox);
ptm_path_analysis_axs[i,1].annotate(f'Nodes: {len(we)}\nPaths: {we_tots}',xy,bbox = annot_bbox);

# %% [markdown]
# # Methylation

# %%
# Writers

Interpro_ID_SET = 'IPR001214'


Interpro_ID_DOT = 'IPR025789'


writer_dom = [Interpro_ID_SET, Interpro_ID_DOT]

# Erasers

Interpro_ID_Amino_ox = 'IPR002937'


Interpro_ID_JmjC = 'IPR003347'


eraser_dom = [Interpro_ID_Amino_ox, Interpro_ID_JmjC]

# Readers
Interpro_ID_TUDOR = 'IPR002999'


Interpro_ID_Agenet = 'IPR008395'


Interpro_ID_PWWP = 'IPR000313'


Interpro_ID_Chromo = 'IPR000953' # actual ID 'IPR023780' but larger domain family is the chromo/chromoshadow


reader_dom = [Interpro_ID_TUDOR, Interpro_ID_Agenet, Interpro_ID_PWWP, Interpro_ID_Chromo]
all_Interpro_IDs = [Interpro_ID_SET, Interpro_ID_DOT,Interpro_ID_Amino_ox,Interpro_ID_JmjC,Interpro_ID_TUDOR,Interpro_ID_Agenet,Interpro_ID_PWWP,Interpro_ID_Chromo]

# %%
methyl_prots = full_ref[full_ref['Interpro Domain Architecture IDs'].apply(lambda y: any([x in y for x in all_Interpro_IDs]))]
complete_methyl_net = dansy.dansy(ref = methyl_prots, n = 10, verbose = False)
system_methyl_net = dansy.dansy(ref=methyl_prots, interproIDs=all_Interpro_IDs, n =10, verbose = False)

# %%
d = system_methyl_net
node_colors = []
for node in d.G.nodes:
    eraser_check = any([k in node for k in eraser_dom])
    writer_check = any([k in node for k in writer_dom])
    reader_check = any([k in node for k in reader_dom])

    if sum([eraser_check, writer_check, reader_check]) > 1:
        node_colors.append(color_cats['Multiple'])
    elif writer_check:
        node_colors.append(color_cats['Writer'])
    elif eraser_check:
        node_colors.append(color_cats['Eraser'])
    elif reader_check:
        node_colors.append(color_cats['Reader'])
    else:
        node_colors.append('#808080')
        #raise ValueError(f'Something went very wrong {node}')
    
pos = nx.nx_agraph.pygraphviz_layout(d.G,prog='sfdp')
nx.draw(d.G, pos,
        node_color=node_colors,
        **network_params, ax = ptm_nets_axs[0])
ptm_nets_axs[0].set_title('Methylation')
# Out:
# Text(0.5, 1.0, 'Methylation')

# %%
for i in range(3):
    ptm_nets_axs[i].set_box_aspect(1)
    ptm_nets_axs[i].axis('on')

color_cats2 = color_cats.copy()
del color_cats2['External']
handles = [Line2D([],[], marker='o', color=v, markersize=4,linestyle='None', markeredgecolor='k', markeredgewidth=0.25) for v in color_cats2.values()]
labels = [k for k in color_cats2.keys()]
ptm_nets_fig.legend(handles, labels, fancybox = False, edgecolor = 'k',loc = 'lower center', ncols = 4,
                borderpad = 0.2, columnspacing = 0.5, handletextpad = 0.25,
                bbox_to_anchor = (0.5,-0.1)).get_frame().set_linewidth(0.5)
ptm_nets_fig
ptm_nets_fig.savefig('Figures/Manuscript/Supplemental_Figure_4/4A_Additional_PTM_System_Networks.svg')

# %%
# Adding in the number of connected components in the full ngram network
ptm_nNet_summary.loc['M','CC'] = nx.number_connected_components(system_methyl_net.G)
ptm_nNet_summary.loc['M','Isolates'] = nx.number_of_isolates(system_methyl_net.G)
ptm_nNet_summary.loc['M','CC Full'] = nx.number_connected_components(complete_methyl_net.G)
ptm_nNet_summary.loc['M','Isolates Full'] = nx.number_of_isolates(complete_methyl_net.G)

# %%
plt.figure(figsize=(2,1.25),dpi=300)
plt.bar(height =ptm_nNet_summary['CC'].tolist(), x = ptm_nNet_summary.index,color=['tab:green','tab:purple','tab:cyan','tab:pink','tab:gray'],edgecolor = 'k',linewidth=0.5)
plt.ylabel('Connected Components')
plt.xlabel('PTM System')
plt.savefig('Figures/Manuscript/Supplemental_Figure_4/4B_Additional_PTM_Systems_Connected_Componets.svg')

# %% [markdown]
# As a small potential analysis we can expand the path analysis to the other systems, but it is not as easy to interpret.

# %%
i = 2

sources = []
for d in writer_dom:
    if d in system_methyl_net.collapsed_ngrams:
            potent_ngrams = [x for x in system_methyl_net.ngrams if d in x ]
            ngram_check = min(potent_ngrams, key = lambda x: len(x.split('|')))
    else:
        ngram_check = d

    sources.append(ngram_check)

targets = []
for d in reader_dom:
    if d in system_methyl_net.collapsed_ngrams:
            potent_ngrams = [x for x in system_methyl_net.ngrams if d in x ]
            ngram_check = min(potent_ngrams, key = lambda x: len(x.split('|')))
    else:
        ngram_check = d

    targets.append(ngram_check)


wr = get_shortest_path_dist(system_methyl_net.G, sources, targets)
wr_tots = wr.filter(sources+targets).max()
wr.drop([x for x in sources+targets if x in wr.index], inplace = True)
w = np.ones(len(wr))/len(wr)
ptm_path_analysis_axs[i,0].hist(wr.div(wr_tots),
            bins = 20,range=(0,1), 
            weights = w,
            edgecolor = 'k',linewidth = 0.5,
            color = 'tab:cyan'
            );

targets = []
for d in eraser_dom:
    if d in system_methyl_net.collapsed_ngrams:
            potent_ngrams = [x for x in system_methyl_net.ngrams if d in x ]
            ngram_check = min(potent_ngrams, key = lambda x: len(x.split('|')))
    else:
        ngram_check = d

    targets.append(ngram_check)

we = get_shortest_path_dist(system_methyl_net.G, sources, targets)
we_tots = we.filter(sources+targets).max()
we.drop([x for x in sources+targets if x in we.index], inplace = True)
w = np.ones(len(we))/len(we)
ptm_path_analysis_axs[i,1].hist(we.div(we_tots),
            bins = 20,range=(0,1), 
            weights = w,
            edgecolor = 'k',linewidth = 0.5,
            color = 'tab:cyan'
            );
if np.isnan(wr_tots):
    wr_tots = 0
if np.isnan(we_tots):
    we_tots = 0
ptm_path_analysis_axs[i,0].annotate(f'Nodes: {len(wr)}\nPaths: {wr_tots}',xy,bbox = annot_bbox);
ptm_path_analysis_axs[i,1].annotate(f'Nodes: {len(we)}\nPaths: {we_tots}',xy,bbox = annot_bbox);

# %%
ptm_path_analysis_axs[0,0].set_title('Writers to Readers')
ptm_path_analysis_axs[0,1].set_title('Writers to Erasers')
ptm_path_analysis_axs[4,0].set_xlabel('Relative Path Fraction')
ptm_path_analysis_axs[4,1].set_xlabel('Relative Path Fraction')

ptm_path_analysis_f.supylabel('Relative Node Fraction')
ptm_path_analysis_f

# %%
sources = []
for d in writer_dom:
    if d in system_methyl_net.collapsed_ngrams:
            potent_ngrams = [x for x in system_methyl_net.ngrams if d in x ]
            ngram_check = min(potent_ngrams, key = lambda x: len(x.split('|')))
    else:
        ngram_check = d
    sources.append(ngram_check)

r_targets = []
for d in reader_dom:
    if d in system_methyl_net.collapsed_ngrams:
            potent_ngrams = [x for x in system_methyl_net.ngrams if d in x ]
            ngram_check = min(potent_ngrams, key = lambda x: len(x.split('|')))
    else:
        ngram_check = d
    r_targets.append(ngram_check)

e_targets = []
for d in eraser_dom:
    if d in system_methyl_net.collapsed_ngrams:
            potent_ngrams = [x for x in system_methyl_net.ngrams if d in x ]
            ngram_check = min(potent_ngrams, key = lambda x: len(x.split('|')))
    else:
        ngram_check = d
    e_targets.append(ngram_check)

wr_len = get_shortest_path_lens(system_methyl_net.G, sources, r_targets)
we_len = get_shortest_path_lens(system_methyl_net.G, sources, e_targets)
ptm_shortest_lens['Methylation'] = {'reader':wr_len,'eraser':we_len}

# %%
t = pd.DataFrame.from_dict(ptm_shortest_lens,orient='index').reset_index(names = 'system')
t= t.melt(id_vars='system').explode('value').reset_index(drop=True)
sns.swarmplot(t, x = 'variable', y = 'value', hue = 'system')
# Out:
# <Axes: xlabel='variable', ylabel='value'>
